# %%
import sqlite3

# %%
conn = sqlite3.connect('practice.db')

cursor = conn.cursor()

# %%
cursor.execute('''
    CREATE TABLE IF NOT EXISTS employees (
        id INTEGER PRIMARY KEY,
        name TEXT NOT NULL,
        role TEXT,
        salary REAL
    )
''')

# %%
cursor.execute("INSERT INTO employees (id, name, role, salary) VALUES (?, ?, ?, ?)",
               ("2", "Shubhank", "Data Analyst", 75000))
conn.commit()

# %%
cursor.execute("SELECT * FROM employees")
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'Shubhank', 'Data Analyst', 75000.0)
# (2, 'Shubhank', 'Data Analyst', 75000.0)
